# %% [markdown]
# <H3>Name - Anushka Pachpute
# <h3>Roll No - 20971
# <h3>College Name - AGC (SDBI)
# <h3>Class - F.Y. BSc Data Science
# <h3>Subject - Principles of Programming Language

# %% [markdown]
# <h2>Assignment 5 : Python Dictionary

# %% [markdown]
# <h4>Question Set A

# %%
# Q.1) Write a program to create a dictionary with roll number as key and name as value for 5 students. Display all key-value pairs
students = {1: "Anu", 2: "Riya", 3: "Aman", 4: "Neha", 5: "Rahul"}

for roll, name in students.items():
    print(roll, ":", name)
# Out:
# 1 : Anu
# 2 : Riya
# 3 : Aman
# 4 : Neha
# 5 : Rahul

# %%
# Q.2) Write a program to count the frequency of each word in a given sentence using a dictionary. 
s="hello world print hello"
words=s.split()
freq={}
for w in words: freq[w]=freq.get(w,0)+1
print(freq)
# Out:
# {'hello': 2, 'world': 1, 'print': 1}

# %%
# Q.3) Write a program to merge two dictionaries entered by the user.
dict1 = {}
n1 = int(input("How many elements in first dictionary? "))
for i in range(n1):
    key = input("Enter key: ")
    value = input("Enter value: ")
    dict1[key] = value

dict2 = {}
n2 = int(input("How many elements in second dictionary? "))
for i in range(n2):
    key = input("Enter key: ")
    value = input("Enter value: ")
    dict2[key] = value

dict1.update(dict2)

print("Merged dictionary:", dict1)
# Out:
# How many elements in first dictionary?  2
# Enter key:  ram
# Enter value:  12
# Enter key:  rohit
# Enter value:  13
# How many elements in second dictionary?  2
# Enter key:  rohmesh
# Enter value:  21
# Enter key:  ramit
# Enter value:  23
# Merged dictionary: {'ram': '12', 'rohit': '13', 'rohmesh': '21', 'ramit': '23'}

# %%
# Q.4) Write a program to find the key with the maximum value in a dictionary
marks = {"Math": 80, "Sci": 90, "Eng": 85}

max_key = max(marks, key=marks.get)
print(max_key)
# Out:
# Sci

# %%
# Q.5) Write a program to check if a given key exists in a dictionary.
student = {"name": "John", "age": 20, "grade": "A"}
if "name" in student:
 print("Name exists")
# Out:
# Name exists

# %% [markdown]
# <h4>Question Set B

# %%
# Q.1) Write a program to remove a key from a dictionary and handle the case when key doesn't exist.
d = {'a': 10, 'b': 25, 'c': 15}
key = input("Enter key to remove: ")

if key in d:
    d.pop(key)  # Remove key
    print("Updated dictionary:", d)
else:
    print("Key does not exist in the dictionary")
# Out:
# Enter key to remove:  b
# Updated dictionary: {'a': 10, 'c': 15}

# %%
# Q.2) Write a program to sort a dictionary by its values in descending order.
d = {'a': 13, 'b': 5, 'c': 27}

sorted_d = dict(sorted(d.items(), key=lambda item: item[1], reverse=True))

print("Dictionary sorted by values (descending):", sorted_d)
# Out:
# Dictionary sorted by values (descending): {'c': 27, 'a': 13, 'b': 5}

# %%
# Q.3) Write a program to create a dictionary from two lists - one containing keys and another containing values
keys = ['a', 'b', 'c']
values = [1, 2, 3]

my_dict = {}

for i in range(len(keys)):
    my_dict[keys[i]] = values[i]

print(my_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# <h4>Question Set C

# %%
# Q.1) Write a program to find all keys with the same value in a dictionary
d = {"a": 1, "b": 2, "c": 1}

value = 1
for k, v in d.items():
    if v == value:
        print(k)
# Out:
# a
# c

# %%
# Q.2) Write a program to create a dictionary where keys are numbers from 1 to n and values are their cubes
n = int(input("Enter a number: "))
d = {}

for i in range(1, n+1):
    d[i] = i**3

print("Dictionary of cubes:", d)
# Out:
# Enter a number:  6
# Dictionary of cubes: {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216}
